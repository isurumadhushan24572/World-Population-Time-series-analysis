# %% [markdown]
# #### Installing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Importing Data Set

# %%
data = pd.read_excel('POPUPLATION.xlsx')

# %%
data.head()
# Out:
#                   Country Name       1960       1961       1962       1963  \
# 0                        Aruba      54608      55811      56682      57475
# 1  Africa Eastern and Southern  130692579  134169237  137835590  141630546
# 2                  Afghanistan    8622466    8790140    8969047    9157465
# 3   Africa Western and Central   97256290   99314028  101445032  103667517
# 4                       Angola    5357195    5441333    5521400    5599827
#
#         1964       1965       1966       1967       1968  ...       2013  \
# 0      58178      58782      59291      59522      59471  ...     102880
# 1  145605995  149742351  153955516  158313235  162875171  ...  567892149
# 2    9355514    9565147    9783147   10010030   10247780  ...   31541209
# 3  105959979  108336203  110798486  113319950  115921723  ...  387204553
# 4    5673199    5736582    5787044    5827503    5868203  ...   26147002
#
#         2014       2015       2016       2017       2018       2019  \
# ...

# %%
data['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
data = data[data["Country Name"].isin(['Sri Lanka','India','China','Ukraine','Russian Federation'])]

# %%
data
# Out:
#            Country Name       1960       1961       1962       1963  \
# 39                China  667070000  660330000  665770000  682335000
# 94                India  445954579  456351876  467024193  477933619
# 117           Sri Lanka    9783871   10022888   10267067   10517531
# 168  Russian Federation  119897000  121236000  122591000  123960000
# 204             Ukraine   42767251   43365219   43924755   44445903
#
#           1964       1965       1966       1967       1968  ...        2013  \
# 39   698355000  715185000  735400000  754550000  774510000  ...  1363240000
# 94   489059309  500114346  510992617  521987069  533431909  ...  1291132063
# 117   10774086   11035224   11299721   11571008   11846815  ...    21131756
# 168  125345000  126745000  127468000  128196000  128928000  ...   143506995
# 204   44941406   45387091   45809120   46235370   46635196  ...    45489648
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %% [markdown]
# #### Get # rows and columns

# %%
data.shape
# Out:
# (5, 64)

# %% [markdown]
# #### Get simple information about data set

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 39 to 204
# Data columns (total 64 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  5 non-null      object
#  1   1960          5 non-null      int64
#  2   1961          5 non-null      int64
#  3   1962          5 non-null      int64
#  4   1963          5 non-null      int64
#  5   1964          5 non-null      int64
#  6   1965          5 non-null      int64
#  7   1966          5 non-null      int64
#  8   1967          5 non-null      int64
#  9   1968          5 non-null      int64
#  10  1969          5 non-null      int64
#  11  1970          5 non-null      int64
#  12  1971          5 non-null      int64
#  13  1972          5 non-null      int64
#  14  1973          5 non-null      int64
#  15  1974          5 non-null      int64
#  16  1975          5 non-null      int64
#  17  1976          5 non-null      int64
# ...

# %% [markdown]
# #### Get summrised Statistical details

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   2.570945e+08  2.582612e+08  2.619154e+08  2.678384e+08  2.736950e+08
# std    2.870844e+08  2.861283e+08  2.895800e+08  2.969708e+08  3.042126e+08
# min    9.783871e+06  1.002289e+07  1.026707e+07  1.051753e+07  1.077409e+07
# 25%    4.276725e+07  4.336522e+07  4.392476e+07  4.444590e+07  4.494141e+07
# 50%    1.198970e+08  1.212360e+08  1.225910e+08  1.239600e+08  1.253450e+08
# 75%    4.459546e+08  4.563519e+08  4.670242e+08  4.779336e+08  4.890593e+08
# max    6.670700e+08  6.603300e+08  6.657700e+08  6.823350e+08  6.983550e+08
#
#                1965          1966          1967          1968          1969  \
# count  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   2.796933e+08  2.861939e+08  2.925079e+08  2.990704e+08  3.060228e+08
# ...

# %% [markdown]
# #### Data Preprocessing part

# %% [markdown]
# ##### Checking Duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Checking Null values

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
# Sort the data in descending order based on the '1960' column
data_sorted = data.sort_values(by='2020', ascending=False)

# Plot the barplot
plt.figure(figsize=(15,8))
ax = sns.barplot(data=data_sorted, x='Country Name', y='2020')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Show the plot

plt.show()

# %%
# Sort the data in descending order based on the '1960' column
data_sorted = data.sort_values(by='2021', ascending=False)

# Plot the barplot
plt.figure(figsize=(15,8))
ax = sns.barplot(data=data_sorted, x='Country Name', y='2021')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Show the plot

plt.show()

# %%
# Sort the data in descending order based on the '1960' column
data_sorted = data.sort_values(by='2022', ascending=False)

# Plot the barplot
plt.figure(figsize=(15,8))
ax = sns.barplot(data=data_sorted, x='Country Name', y='2022')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Show the plot

plt.show()

# %%
data_transposed = data.melt(id_vars=['Country Name'], var_name='Year', value_name='Value')

# Filter the data for the years you want (1961 to 2022)
data_filtered = data_transposed[(data_transposed['Year'] >= '1961') & (data_transposed['Year'] <= '2022')]

# Sort the data in descending order based on the 'Value' column
data_sorted = data_filtered.sort_values(by='Value', ascending=False)

# Plot the barplot
plt.figure(figsize=(18, 6))  # Adjust figure size as needed
ax = sns.barplot(data=data_sorted, x='Country Name', y='Value', hue='Year')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Show the legend horizontally at the top
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=5, title="Year", title_fontsize='large')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming data is your DataFrame containing the relevant data

# Transpose the DataFrame so that years become rows
data_transposed = data.melt(id_vars=['Country Name'], var_name='Year', value_name='Value')

# Filter the data for the years you want (1960 to 2022)
data_filtered = data_transposed[(data_transposed['Year'] >= '1960') & (data_transposed['Year'] <= '2022')]

# Plot the line chart
plt.figure(figsize=(15, 6))  # Adjust figure size as needed
ax = sns.lineplot(data=data_filtered, x='Year', y='Value', hue='Country Name')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Show the legend horizontally at the top
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=5, title="Country Name", title_fontsize='large')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming data is your DataFrame containing the relevant data

# Transpose the DataFrame so that years become rows
data_transposed = data.melt(id_vars=['Country Name'], var_name='Year', value_name='Value')

# Filter the data for the years you want (1960 to 2022)
data_filtered = data_transposed[(data_transposed['Year'] >= '1960') & (data_transposed['Year'] <= '2022')]

# Get unique country names
countries = data_filtered['Country Name'].unique()

# Plot individual line charts for each country
plt.figure(figsize=(20, 6))  # Adjust figure size as needed
for country in countries:
    plt.figure(figsize=(20, 6))
    country_data = data_filtered[data_filtered['Country Name'] == country]
    ax = sns.lineplot(data=country_data, x='Year', y='Value', label=country)

    # Rotate x-axis labels for better readability if needed
    plt.xticks(rotation=90)
    
    plt.title(country)  # Add title for each chart
    plt.xlabel('Year')  # Add x-axis label
    plt.ylabel('Value')  # Add y-axis label
    plt.legend(title='Country Name', title_fontsize='large')  # Add legend

    # Show the plot for each country
    plt.show()

# %%
data.head()
# Out:
#            Country Name       1960       1961       1962       1963  \
# 39                China  667070000  660330000  665770000  682335000
# 94                India  445954579  456351876  467024193  477933619
# 117           Sri Lanka    9783871   10022888   10267067   10517531
# 168  Russian Federation  119897000  121236000  122591000  123960000
# 204             Ukraine   42767251   43365219   43924755   44445903
#
#           1964       1965       1966       1967       1968  ...        2013  \
# 39   698355000  715185000  735400000  754550000  774510000  ...  1363240000
# 94   489059309  500114346  510992617  521987069  533431909  ...  1291132063
# 117   10774086   11035224   11299721   11571008   11846815  ...    21131756
# 168  125345000  126745000  127468000  128196000  128928000  ...   143506995
# 204   44941406   45387091   45809120   46235370   46635196  ...    45489648
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %%
data = data.rename(columns={'Country Name': 'Country'})

# %%
data.head()
# Out:
#                 Country       1960       1961       1962       1963  \
# 39                China  667070000  660330000  665770000  682335000
# 94                India  445954579  456351876  467024193  477933619
# 117           Sri Lanka    9783871   10022888   10267067   10517531
# 168  Russian Federation  119897000  121236000  122591000  123960000
# 204             Ukraine   42767251   43365219   43924755   44445903
#
#           1964       1965       1966       1967       1968  ...        2013  \
# 39   698355000  715185000  735400000  754550000  774510000  ...  1363240000
# 94   489059309  500114346  510992617  521987069  533431909  ...  1291132063
# 117   10774086   11035224   11299721   11571008   11846815  ...    21131756
# 168  125345000  126745000  127468000  128196000  128928000  ...   143506995
# 204   44941406   45387091   45809120   46235370   46635196  ...    45489648
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %%
china = data[data['Country'] == 'China'].drop(columns='Country')

# %%
china= china.transpose()

# %%
# china = china.transpose()
china = china.rename(columns={39:'Population'})

# %%
china.head()
# Out:
#       Population
# 1960   667070000
# 1961   660330000
# 1962   665770000
# 1963   682335000
# 1964   698355000

# %%
china.shape
# Out:
# (63, 1)

# %% [markdown]
# ### ADF Test [ Checking Stationary Part]

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# Null Hypothesis :- Data set is Not Stationary
#
# Alternative Hypothesis :- Data set is  Stationary

# %%
result = adfuller(china['Population'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print(f'Critical Values:{result[4]}')

if result[1] < 0.05 :
    print('Series is  stationary')
else:
    print('Series is Not stationary')
# Out:
# ADF Statistic: -1.669926
# p-value: 0.446670
# Critical Values:{'1%': -3.5656240522121956, '5%': -2.920142229157715, '10%': -2.598014675124952}
# Series is Not stationary

# %% [markdown]
# ### KPSS Test

# %%
from statsmodels.tsa.stattools import kpss

# %% [markdown]
# Null Hypothesis :- Data set is Stationary
#
# Alternative Hypothesis :- Data set is not Stationary

# %%
stats, p, lags, critical_value = kpss(china['Population'])
print('p-value: %f' % p)
print('statistics: %s' % stats)
print('critical_value: %s' % critical_value)

if p < 0.05:
    print('Series is Not stationary')
else:
    print('Series is stationary')
# Out:
# p-value: 0.010000
# statistics: 1.1315268643792258
# critical_value: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# Series is Not stationary
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# #### After First Defferencing the data set

# %%
df1 = china.diff().dropna()

# %% [markdown]
# ### KPSS Test

# %%
stats, p, lags, critical_value = kpss(df1['Population'])
print('p-value: %f' % p)
print('statistics: %s' % stats)
print('critical_value: %s' % critical_value)

if p < 0.05:
    print('Series is Not stationary')
else:
    print('Series is stationary')
# Out:
# p-value: 0.010000
# statistics: 0.8015616096485798
# critical_value: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# Series is Not stationary
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# ### ADF Test

# %%
result = adfuller(df1['Population'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print(f'Critical Values:{result[4]}')

if result[1] < 0.1 :
    print('Series is  stationary')
else:
    print('Series is Not stationary')
# Out:
# ADF Statistic: 0.456800
# p-value: 0.983499
# Critical Values:{'1%': -3.5656240522121956, '5%': -2.920142229157715, '10%': -2.598014675124952}
# Series is Not stationary

# %% [markdown]
# ### 2nd Defferencing

# %%
df2 = china.diff().diff().dropna()

# %% [markdown]
# #### KPSS Test

# %%
stats, p, lags, critical_value = kpss(df2['Population'])
print('p-value: %f' % p)
print('statistics: %s' % stats)
print('critical_value: %s' % critical_value)

if p < 0.05:
    print('Series is Not stationary')
else:
    print('Series is stationary')
# Out:
# p-value: 0.053667
# statistics: 0.4544915217262556
# critical_value: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# Series is stationary

# %% [markdown]
# #### ADF Test

# %%
result = adfuller(df2['Population'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print(f'Critical Values:{result[4]}')

if result[1] < 0.1 :
    print('Series is  stationary')
else:
    print('Series is Not stationary')
# Out:
# ADF Statistic: -3.276346
# p-value: 0.015970
# Critical Values:{'1%': -3.5656240522121956, '5%': -2.920142229157715, '10%': -2.598014675124952}
# Series is  stationary

# %% [markdown]
# #### Finding No of defferences

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Import data
df = china

# Original Series
fig, axes = plt.subplots(4, 2, sharex=True)
axes[0, 0].plot(df.Population); axes[0, 0].set_title('Original Series')
plot_acf(df.Population, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.Population.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.Population.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df.Population.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.Population.diff().diff().dropna(), ax=axes[2, 1])

# 3rd Differencing
axes[3, 0].plot(df.Population.diff().diff().diff()); axes[3, 0].set_title('3rd Order Differencing')
plot_acf(df.Population.diff().diff().diff().dropna(), ax=axes[3, 1])

# # 4th Differencing
# axes[4, 0].plot(df.Population.diff().diff().diff().diff()); axes[4, 0].set_title('4th Order Differencing')
# plot_acf(df.Population.diff().diff().diff().diff().dropna(), ax=axes[4, 1])


plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(china.Population.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.669926
# p-value: 0.446670

# %%
from pmdarima.arima.utils import ndiffs
y = china.Population

# Perform ADF test
adf_diffs = ndiffs(y, test='adf')

# Perform KPSS test
kpss_diffs = ndiffs(y, test='kpss')

# Perform PP test
pp_diffs = ndiffs(y, test='pp')

# Combine all results into a list
diffs_list = [adf_diffs, kpss_diffs, pp_diffs]

print("ADF test:", adf_diffs)
print("KPSS test:", kpss_diffs)
print("PP test:", pp_diffs)
print("All results as a list:", diffs_list)
# Out:
# ADF test: 2
# KPSS test: 2
# PP test: 1
# All results as a list: [2, 2, 1]

# %% [markdown]
# Finaly choosen No of Deferrence as :- 2

# %% [markdown]
# ### Finding order of AR ==> No of lag observations [p]

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf

plt.rcParams.update({'figure.figsize': (15, 9), 'figure.dpi': 120})

fig, axes = plt.subplots(3, 1, sharex=True)

# 1st Differencing
axes[0].plot(china.Population.diff())
axes[0].set_title('1st Differencing')
plot_pacf(china.Population.diff().dropna(), ax=axes[0])

# 2nd Differencing
axes[1].plot(china.Population.diff().diff())
axes[1].set_title('2nd Differencing')
plot_pacf(china.Population.diff().diff().dropna(), ax=axes[1])

# 3rd Differencing
axes[2].plot(china.Population.diff().diff().diff())
axes[2].set_title('3rd Differencing')
plt.xticks(rotation='vertical')  # Rotate x-axis labels vertically
plot_pacf(china.Population.diff().diff().diff().dropna(), ax=axes[2])

plt.show()

# %% [markdown]
# Finaly choosen order of AR as :- 2 (p)

# %% [markdown]
# ### Finding order of MA ==> No of resedulas observations [q]

# %% [markdown]
# # MA==> q

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Import data
df = china

# Original Series
fig, axes = plt.subplots(4, 2, sharex=True)
axes[0, 0].plot(df.Population); axes[0, 0].set_title('Original Series')
plot_acf(df.Population, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.Population.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.Population.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df.Population.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.Population.diff().diff().dropna(), ax=axes[2, 1])

# 3rd Differencing
axes[3, 0].plot(df.Population.diff().diff().diff()); axes[3, 0].set_title('3rd Order Differencing')
plot_acf(df.Population.diff().diff().diff().dropna(), ax=axes[3, 1])

# %% [markdown]
# Finaly choosen order of MA as :- 0 (q)

# %% [markdown]
# # ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'train' is your DataFrame containing the time series data
# and 'Population' is the column containing the population data

# Instantiate the ARIMA model with the order parameter (2, 2, 0)
model = ARIMA(china['Population'], order=(2, 2, 0))

# Fit the ARIMA model
model = model.fit()

# Print model summary
print(model.summary())
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:             Population   No. Observations:                   63
# Model:                 ARIMA(2, 2, 0)   Log Likelihood                -937.037
# Date:                Sat, 06 Apr 2024   AIC                           1880.073
# ...

# %%
# Plot residual errors
residuals = pd.DataFrame(model.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
print(china.shape)
train =china.iloc[:-13]
test = china.iloc[-13:]
print(train.shape,test.shape)
# Out:
# (63, 1)
# (50, 1) (13, 1)

# %%
# Build Model

model = ARIMA(train.Population, order=(2, 2, 0))  
fitted = model.fit()  
# Print model summary
print(fitted.summary())
# Forecast
fc = fitted.forecast(15)  # Forecast 15 steps ahead

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.xticks(rotation='vertical')  # Rotate x-axis labels vertically
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:             Population   No. Observations:                   50
# Model:                 ARIMA(2, 2, 0)   Log Likelihood                -735.454
# Date:                Sat, 06 Apr 2024   AIC                           1476.909
# ...

# %%
start = len(train)
end = len(train) + len(test)-1
pred = fitted.predict(start=start,end=end,type='levels')
print(pred)
pred.index = china.index[start:end+1]
# Out:
# 2010-01-01    1.337873e+09
# 2011-01-01    1.344490e+09
# 2012-01-01    1.351106e+09
# 2013-01-01    1.357723e+09
# 2014-01-01    1.364339e+09
# 2015-01-01    1.370955e+09
# 2016-01-01    1.377572e+09
# 2017-01-01    1.384188e+09
# 2018-01-01    1.390805e+09
# 2019-01-01    1.397421e+09
# 2020-01-01    1.404037e+09
# 2021-01-01    1.410654e+09
# 2022-01-01    1.417270e+09
# Freq: AS-JAN, Name: predicted_mean, dtype: float64

# %%
pred.plot(legend=True)
test['Population'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt

# Calculate Mean Squared Error
MSE = mean_squared_error(pred, test['Population'])

# Calculate Root Mean Squared Error
RMSE = sqrt(MSE)

# Calculate Mean Absolute Percentage Error
MAPE = mean_absolute_error(test['Population'], pred) / test['Population'].mean() * 100

# Print the errors
print(f'Mean Squared Error: {MSE}')
print(f'Root Mean Squared Error: {RMSE}')
print(f'Mean Absolute Percentage Error: {MAPE}%')
# Out:
# Mean Squared Error: 58089014083205.01
# Root Mean Squared Error: 7621614.926195432
# Mean Absolute Percentage Error: 0.4684027040238889%

# %%
from pmdarima import auto_arima
stepwise_fit = auto_arima(train['Population'],trace= True,suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=1508.512, Time=0.94 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1556.665, Time=0.06 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1539.019, Time=0.08 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1602.072, Time=0.09 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=1501.316, Time=0.21 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=1487.899, Time=0.09 sec
#  ARIMA(0,2,3)(0,0,0)[0]             : AIC=1522.886, Time=0.07 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1508.163, Time=0.13 sec
#  ARIMA(1,2,3)(0,0,0)[0]             : AIC=1530.860, Time=0.11 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=1490.752, Time=0.05 sec
#
# Best model:  ARIMA(0,2,2)(0,0,0)[0]
# Total fit time: 1.842 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   50
# ...

# %%
# Build Model

model = ARIMA(train.Population, order=(0, 2, 2))  
fitted = model.fit()  
# Print model summary
print(fitted.summary())
# Forecast
fc = fitted.forecast(15)  # Forecast 15 steps ahead

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.xticks(rotation='vertical')  # Rotate x-axis labels vertically
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:             Population   No. Observations:                   50
# Model:                 ARIMA(0, 2, 2)   Log Likelihood                -740.949
# Date:                Sat, 06 Apr 2024   AIC                           1487.899
# ...

# %%
start = len(train)
end = len(train) + len(test)-1
pred = fitted.predict(start=start,end=end,type='levels')
print(pred)
pred.index = china.index[start:end+1]
# Out:
# 2010-01-01    1.337873e+09
# 2011-01-01    1.344490e+09
# 2012-01-01    1.351106e+09
# 2013-01-01    1.357723e+09
# 2014-01-01    1.364339e+09
# 2015-01-01    1.370955e+09
# 2016-01-01    1.377572e+09
# 2017-01-01    1.384188e+09
# 2018-01-01    1.390805e+09
# 2019-01-01    1.397421e+09
# 2020-01-01    1.404037e+09
# 2021-01-01    1.410654e+09
# 2022-01-01    1.417270e+09
# Freq: AS-JAN, Name: predicted_mean, dtype: float64

# %%
pred = fitted.predict(start=end,end=end+8,type='levels')
pred
# Out:
# 2022-01-01    1.417270e+09
# 2023-01-01    1.423887e+09
# 2024-01-01    1.430503e+09
# 2025-01-01    1.437119e+09
# 2026-01-01    1.443736e+09
# 2027-01-01    1.450352e+09
# 2028-01-01    1.456969e+09
# 2029-01-01    1.463585e+09
# 2030-01-01    1.470201e+09
# Freq: AS-JAN, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt

# Calculate Mean Squared Error
MSE = mean_squared_error(pred, test['Population'])

# Calculate Root Mean Squared Error
RMSE = sqrt(MSE)

# Calculate Mean Absolute Percentage Error
MAPE = mean_absolute_error(test['Population'], pred) / test['Population'].mean() * 100

# Print the errors
print(f'Mean Squared Error: {MSE}')
print(f'Root Mean Squared Error: {RMSE}')
print(f'Mean Absolute Percentage Error: {MAPE}%')
# Out:
# Mean Squared Error: 57958583727564.04
# Root Mean Squared Error: 7613053.5087810885
# Mean Absolute Percentage Error: 0.46785001171972046%

# %%
fitted.plot_diagnostics(figsize=(9,7))
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit SARIMAX model
model = SARIMAX(train.Population, order=(0, 2, 2))
fitted_model = model.fit()

# Forecast
n_periods = 24
forecast = fitted_model.forecast(steps=n_periods)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train.Population, label='Training Data')
plt.plot(fitted_model.fittedvalues, color='red', label='Fitted Values')
plt.plot(pd.Series(forecast, index=test.index), color='green', label='Forecast')
plt.xticks(rotation='vertical')  # Rotate x-axis labels vertically
plt.title("ARIMA Model with SARIMAX")
plt.legend()
plt.show()
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)

# %%
pred = fitted_model.predict(start=start,end=end+8,type='levels')
pred
# Out:
# 2010-01-01    1.337873e+09
# 2011-01-01    1.344490e+09
# 2012-01-01    1.351106e+09
# 2013-01-01    1.357723e+09
# 2014-01-01    1.364339e+09
# 2015-01-01    1.370955e+09
# 2016-01-01    1.377572e+09
# 2017-01-01    1.384188e+09
# 2018-01-01    1.390805e+09
# 2019-01-01    1.397421e+09
# 2020-01-01    1.404037e+09
# 2021-01-01    1.410654e+09
# 2022-01-01    1.417270e+09
# 2023-01-01    1.423887e+09
# 2024-01-01    1.430503e+09
# 2025-01-01    1.437119e+09
# 2026-01-01    1.443736e+09
# 2027-01-01    1.450352e+09
# 2028-01-01    1.456969e+09
# 2029-01-01    1.463585e+09
# 2030-01-01    1.470201e+09
# Freq: AS-JAN, Name: predicted_mean, dtype: float64

# %%
china.tail(15)
# Out:
#       Population
# 2008  1324655000
# 2009  1331260000
# 2010  1337705000
# 2011  1345035000
# 2012  1354190000
# 2013  1363240000
# 2014  1371860000
# 2015  1379860000
# 2016  1387790000
# 2017  1396215000
# 2018  1402760000
# 2019  1407745000
# 2020  1411100000
# 2021  1412360000
# 2022  1412175000
